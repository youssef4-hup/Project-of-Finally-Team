# %%
import pandas as pd
df = pd.read_csv("Dataset/hospital.csv" , on_bad_lines = 'skip')
df
# Out:
#                Timestamp       كم يبلغ عمرك الجنس  \
# 0    28/09/2025 18:35:07                 19   ذكر
# 1    28/09/2025 18:46:18                 24   ذكر
# 2    07/10/2025 19:23:58  18 year - 29 year   ذكر
# 3    07/10/2025 19:28:20  18 year - 29 year   ذكر
# 4    07/10/2025 19:30:28  18 year - 29 year   ذكر
# ..                   ...                ...   ...
# 196  19/10/2025 22:14:45  18 year - 29 year  أنثى
# 197  20/10/2025 16:10:16  18 year - 29 year   ذكر
# 198  23/10/2025 00:35:36  18 year - 29 year  أنثى
# 199  26/10/2025 02:04:17  18 year - 29 year   ذكر
# 200  26/10/2025 12:19:57  18 year - 29 year   ذكر
#
#       ​ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟    \
# 0                                  كشف في عيادة خارجية
# 1                                 إجراء فحوصات أو أشعة
# 2                                         عملية جراحية
# 3                                 إجراء فحوصات أو أشعة
# 4                                          قسم الطوارئ
# ...

# %%
df.head(2)
# Out:
#              Timestamp كم يبلغ عمرك الجنس  \
# 0  28/09/2025 18:35:07           19   ذكر
# 1  28/09/2025 18:46:18           24   ذكر
#
#     ​ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟    \
# 0                                كشف في عيادة خارجية
# 1                               إجراء فحوصات أو أشعة
#
#     هل هذه زيارتك الأولى لهذه المنشأة؟     أنت    \
# 0                                     لا    مريض
# 1                                     لا    مريض
#
#       كيف تقيّم سهولة الحصول على موعد؟ (1: صعب جداً، 5: سهل جداً)   \
# 0                                                  4
# 1                                                  3
#
#     ما هي المدة التي انتظرتها من وقت حجز الموعد حتى يوم الكشف الفعلي؟    \
# 0                                    في حدود الساعة
# 1                                               يوم
#
#      كيف تقيّم سهولة الوصول إلى موقع المستشفى/الوحدة الصحية؟   (1: صعب جداً، 5: سهل جداً)  \
# 0                                                  1
# ...

# %%
df.tail()
# Out:
#                Timestamp       كم يبلغ عمرك الجنس  \
# 196  19/10/2025 22:14:45  18 year - 29 year  أنثى
# 197  20/10/2025 16:10:16  18 year - 29 year   ذكر
# 198  23/10/2025 00:35:36  18 year - 29 year  أنثى
# 199  26/10/2025 02:04:17  18 year - 29 year   ذكر
# 200  26/10/2025 12:19:57  18 year - 29 year   ذكر
#
#       ​ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟    \
# 196                                كشف في عيادة خارجية
# 197                          تنويم (إقامة في المستشفى)
# 198                               إجراء فحوصات أو أشعة
# 199                                كشف في عيادة خارجية
# 200                               إجراء فحوصات أو أشعة
#
#       هل هذه زيارتك الأولى لهذه المنشأة؟     أنت    \
# 196                                    نعم   مرافق
# 197                                    نعم    مريض
# 198                                     لا    مريض
# 199                                     لا    مريض
# 200                                     لا    مريض
#
# ...

# %%
df.shape
# Out:
# (201, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 47 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Timestamp                                                                                         201 non-null    object
#  1   كم يبلغ عمرك                                                                                      201 non-null    object
#  2   الجنس                                                                                             201 non-null    object
#  3     ​ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟                                       201 non-null    object
# ...

# %%
df.describe()
# Out:
#           كيف تقيّم سهولة الحصول على موعد؟ (1: صعب جداً، 5: سهل جداً)   \
# count                                         201.000000
# mean                                            3.462687
# std                                             1.256921
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             4.000000
# max                                             5.000000
#
#          كيف تقيّم سهولة الوصول إلى موقع المستشفى/الوحدة الصحية؟   (1: صعب جداً، 5: سهل جداً)  \
# count                                         201.000000
# mean                                            3.487562
# std                                             1.288835
# min                                             1.000000
# 25%                                             3.000000
# ...

# %%
df.nunique()
# Out:
# Timestamp                                                                                           188
# كم يبلغ عمرك                                                                                          9
# الجنس                                                                                                 2
#   ​ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟                                           5
#   هل هذه زيارتك الأولى لهذه المنشأة؟                                                                  2
#   أنت                                                                                                 3
#    كيف تقيّم سهولة الحصول على موعد؟ (1: صعب جداً، 5: سهل جداً)                                        5
#   ما هي المدة التي انتظرتها من وقت حجز الموعد حتى يوم الكشف الفعلي؟                                  11
#   كيف تقيّم سهولة الوصول إلى موقع المستشفى/الوحدة الصحية؟   (1: صعب جداً، 5: سهل جداً)                5
# ...

# %%
df.columns = df.columns.str.strip()
df.columns = df.columns.str.replace('\u200f', '', regex=True)
df.columns = df.columns.str.replace('\u200b', '', regex=True)
df.columns = df.columns.str.replace('​', '', regex=True)

print(df.columns.tolist())
# Out:
# ['Timestamp', 'كم يبلغ عمرك', 'الجنس', 'ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟', 'هل هذه زيارتك الأولى لهذه المنشأة؟', 'أنت', 'كيف تقيّم سهولة الحصول على موعد؟ (1: صعب جداً، 5: سهل جداً)', 'ما هي المدة التي انتظرتها من وقت حجز الموعد حتى يوم الكشف الفعلي؟', 'كيف تقيّم سهولة الوصول إلى موقع المستشفى/الوحدة الصحية؟   (1: صعب جداً، 5: سهل جداً)', 'هل كانت اللافتات الإرشادية داخل المنشأة واضحة وكافية للوصول إلى وجهتك؟', 'كيف تقيّم لطف وحسن تعامل موظفي الاستقبال؟ (1:سئ، 5: ممتاز)', 'ما هي مدة انتظارك في منطقة الاستقبال قبل تسجيل بياناتك؟', 'كيف تقيّم وضوح الإجراءات المتبعة عند التسجيل؟ (1:سئ، 5: ممتاز)', 'ما مدى رضاك عن نظافة ومستوى الراحة في منطقة الانتظار الرئيسية؟  (1:سئ، 5: ممتاز)', 'كم من الوقت انتظرت في منطقة الانتظار قبل رؤية الطبيب؟', 'كيف تقيّم مدى اهتمام الممرض/الممرضة بالاستماع إليك؟ (1:سئ، 5: ممتاز)', 'إلى أي مدى شعرت بالاحترام والتعاطف من قبل فريق التمريض؟   (1:سئ، 5: ممتاز)', 'هل قام فريق التمريض بتقديم أنفسهم وشرح الإجراءات التي يقومون بها؟', 'كيف تقيّم سر
# ...

# %%
rename_dict = {
    'كم يبلغ عمرك': 'العمر',
    'الجنس': 'النوع',
    'ما هو نوع الخدمة التي تلقيتها اليوم/خلال زيارتك الأخيرة؟': 'نوع_الخدمة',
    'هل هذه زيارتك الأولى لهذه المنشأة؟': 'زيارة_أولى',
    'أنت': 'الفئة',
    'كيف تقيّم سهولة الحصول على موعد؟ (1: صعب جداً، 5: سهل جداً)': 'سهولة_الحجز',
    'ما هي المدة التي انتظرتها من وقت حجز الموعد حتى يوم الكشف الفعلي؟': 'مدة_الانتظار_قبل_الكشف',
    'كيف تقيّم سهولة الوصول إلى موقع المستشفى/الوحدة الصحية؟   (1: صعب جداً، 5: سهل جداً)': 'سهولة_الوصول',
    'هل كانت اللافتات الإرشادية داخل المنشأة واضحة وكافية للوصول إلى وجهتك؟': 'وضوح_اللافتات',
    'كيف تقيّم لطف وحسن تعامل موظفي الاستقبال؟ (1:سئ، 5: ممتاز)': 'تعامل_الاستقبال',
    'ما هي مدة انتظارك في منطقة الاستقبال قبل تسجيل بياناتك؟': 'مدة_انتظار_الاستقبال',
    'كيف تقيّم وضوح الإجراءات المتبعة عند التسجيل؟ (1:سئ، 5: ممتاز)': 'وضوح_الإجراءات',
    'ما مدى رضاك عن نظافة ومستوى الراحة في منطقة الانتظار الرئيسية؟  (1:سئ، 5: ممتاز)': 'نظافة_الانتظار',
    'كم من الوقت انتظرت في منطقة الانتظار قبل رؤية الطبيب؟': 'مدة_الانتظار_قبل_الطبيب',
    'كيف تقيّم مدى اهتمام الممرض/الممرضة بالاستماع إليك؟ (1:سئ، 5: ممتاز)': 'اهتمام_التمريض',
    'إلى أي مدى شعرت بالاحترام والتعاطف من قبل فريق التمريض؟   (1:سئ، 5: ممتاز)': 'احترام_التمريض',
    'هل قام فريق التمريض بتقديم أنفسهم وشرح الإجراءات التي يقومون بها؟': 'شرح_التمريض',
    'كيف تقيّم سرعة استجابة التمريض عند طلب المساعدة؟  سهل جداً  (1:سئ، 5: ممتاز)': 'استجابة_التمريض',
    'هل استمع الطبيب جيداً لشرحك لحالتك الصحية؟': 'استماع_الطبيب',
    'ما مدى رضاك عن الوقت الذي خصصه الطبيب لك؟   (1:سئ، 5: ممتاز)': 'وقت_الطبيب',
    'كيف تقيّم وضوح شرح الطبيب لتشخيص حالتك؟   (1:سئ، 5: ممتاز)': 'وضوح_الشرح',
    'هل أشركك الطبيب في القرارات المتعلقة بخطتك العلاجية؟': 'مشاركة_الطبيب',
    'هل شعرت بالراحة في طرح الأسئلة على الطبيب؟': 'راحة_الأسئلة',
    'هل أجاب الطبيب على جميع استفساراتك بطريقة مفهومة؟': 'إجابات_الطبيب',
    'كيف تقيّم مستوى الثقة الذي شعرت به تجاه طبيبك المعالج؟   (1:سئ، 5: ممتاز)': 'ثقة_بالطبيب',
    'كيف تقيّم مستوى نظافة الغرف؟ (1:سئ، 5: ممتاز)': 'نظافة_الغرف',
    'هل شعرت بأن خصوصيتك تم احترامها أثناء الكشف والعلاج؟': 'احترام_الخصوصية',
    'كيف تقيّم مستوى الهدوء وقلة الإزعاج في المنشأة؟   (1:سئ، 5: ممتاز)': 'الهدوء',
    'ما مدى رضاك عن جودة الوجبات المقدمة (في حال الاقامة)؟   (1:سئ، 5: ممتاز)': 'جودة_الوجبات',
    'هل كانت المرافق (مثل دورات المياه، الكافيتريا) متاحة وسهلة الاستخدام؟': 'سهولة_المرافق',
    'هل تم شرح الفحوصات أو الإجراءات الطبية لك بوضوح قبل إجرائها؟': 'شرح_الفحوصات',
    'إذا كنت تعاني من ألم، كيف تقيّم اهتمام الفريق الطبي بالسيطرة عليه؟  (1:سئ، 5: ممتاز)': 'السيطرة_على_الألم',
    'هل تم تزويدك بمعلومات واضحة حول الأدوية التي وصفت لك (الجرعة، الآثار الجانبية)؟': 'معلومات_الأدوية',
    'كيف تقيّم التنسيق بين الأقسام المختلفة (مثلاً بين الطبيب والمختبر والأشعة)؟': 'تنسيق_الأقسام',
    'كيف تقيّم وضوح الفواتير والتكاليف المالية للخدمة؟    (1:سئ، 5: ممتاز)': 'وضوح_الفواتير',
    'هل قام الموظفون بشرح ما يغطيه تأمينك الصحي (إن وجد) بوضوح؟': 'توضيح_التأمين',
    'كيف تقيّم سهولة وسرعة إجراءات الخروج من المستشفى (في حال الاقامة)؟  (1: صعب جداً، 5: سهل جداً)': 'سهولة_الخروج',
    'بشكل عام، ما مدى رضاك عن الرعاية التي تلقيتها في هذه الزيارة؟   (1:سئ، 5: ممتاز)': 'الرضا_العام',
    'إلى أي مدى توصي بالمنشأت الصحية الحكومية لعائلتك وأصدقائك؟  (1:سئ، 5: ممتاز)': 'التوصية',
    'ما هو أفضل شيء في التجربة التي مررت بها؟': 'أفضل_شيء',
    'ما هو أكثر شيء يحتاج إلى تحسين من وجهة نظرك؟': 'التحسينات',
    'هل لديك أي اقتراحات إضافية للمساعدة في تحسين خدماتنا؟': 'اقتراحات',
    'كيف تقييم الراحة فى الدفع؟  (1:سئ، 5: ممتاز)': 'راحة_الدفع',
    'كيف تقيّم مستوى نظافة الممرات؟  (1:سئ، 5: ممتاز)': 'نظافة_الممرات',
    'كيف تقيّم مستوى نظافة دورات المياه؟     (1:سئ، 5: ممتاز)': 'نظافة_الحمامات'
}

# %%
df.rename(columns=rename_dict, inplace=True)

# %%
print(df.columns.tolist())
# Out:
# ['Timestamp', 'العمر', 'النوع', 'نوع_الخدمة', 'زيارة_أولى', 'الفئة', 'سهولة_الحجز', 'مدة_الانتظار_قبل_الكشف', 'سهولة_الوصول', 'وضوح_اللافتات', 'تعامل_الاستقبال', 'مدة_انتظار_الاستقبال', 'وضوح_الإجراءات', 'نظافة_الانتظار', 'مدة_الانتظار_قبل_الطبيب', 'اهتمام_التمريض', 'احترام_التمريض', 'شرح_التمريض', 'استجابة_التمريض', 'استماع_الطبيب', 'وقت_الطبيب', 'وضوح_الشرح', 'مشاركة_الطبيب', 'راحة_الأسئلة', 'إجابات_الطبيب', 'ثقة_بالطبيب', 'نظافة_الغرف', 'احترام_الخصوصية', 'الهدوء', 'جودة_الوجبات', 'سهولة_المرافق', 'شرح_الفحوصات', 'السيطرة_على_الألم', 'معلومات_الأدوية', 'تنسيق_الأقسام', 'وضوح_الفواتير', 'توضيح_التأمين', 'سهولة_الخروج', 'الرضا_العام', 'التوصية', 'أفضل_شيء', 'التحسينات', 'اقتراحات', 'راحة_الدفع', 'هل هناك طرق مختلفة للدفع؟', 'نظافة_الممرات', 'نظافة_الحمامات']

# %%
df
# Out:
#                Timestamp              العمر النوع                 نوع_الخدمة  \
# 0    28/09/2025 18:35:07                 19   ذكر        كشف في عيادة خارجية
# 1    28/09/2025 18:46:18                 24   ذكر       إجراء فحوصات أو أشعة
# 2        7/10/2025 19:23  18 year - 29 year   ذكر               عملية جراحية
# 3        7/10/2025 19:28  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
# 4        7/10/2025 19:30  18 year - 29 year   ذكر                قسم الطوارئ
# ..                   ...                ...   ...                        ...
# 196  19/10/2025 22:14:45  18 year - 29 year  أنثى        كشف في عيادة خارجية
# 197  20/10/2025 16:10:16  18 year - 29 year   ذكر  تنويم (إقامة في المستشفى)
# 198  23/10/2025 00:35:36  18 year - 29 year  أنثى       إجراء فحوصات أو أشعة
# 199  26/10/2025 02:04:17  18 year - 29 year   ذكر        كشف في عيادة خارجية
# 200  26/10/2025 12:19:57  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  201 non-null    object
#  1   العمر                      201 non-null    object
#  2   النوع                      201 non-null    object
#  3   نوع_الخدمة                 201 non-null    object
#  4   زيارة_أولى                 201 non-null    object
#  5   الفئة                      201 non-null    object
#  6   سهولة_الحجز                201 non-null    int64
#  7   مدة_الانتظار_قبل_الكشف     201 non-null    object
#  8   سهولة_الوصول               201 non-null    int64
#  9   وضوح_اللافتات              201 non-null    object
#  10  تعامل_الاستقبال            201 non-null    int64
#  11  مدة_انتظار_الاستقبال       201 non-null    object
#  12  وضوح_الإجراءات             201 non-null    int64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.nunique()
# Out:
# Timestamp                    188
# العمر                          9
# النوع                          2
# نوع_الخدمة                     5
# زيارة_أولى                     2
# الفئة                          3
# سهولة_الحجز                    5
# مدة_الانتظار_قبل_الكشف        11
# سهولة_الوصول                   5
# وضوح_اللافتات                  2
# تعامل_الاستقبال                5
# مدة_انتظار_الاستقبال           8
# وضوح_الإجراءات                 5
# نظافة_الانتظار                 5
# مدة_الانتظار_قبل_الطبيب       11
# اهتمام_التمريض                 5
# احترام_التمريض                 5
# شرح_التمريض                    2
# استجابة_التمريض                5
# استماع_الطبيب                  2
# وقت_الطبيب                     5
# وضوح_الشرح                     5
# مشاركة_الطبيب                  2
# راحة_الأسئلة                   3
# إجابات_الطبيب                  2
# ثقة_بالطبيب                    5
# نظافة_الغرف                    5
# احترام_الخصوصية                3
# ...

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='mixed', dayfirst=True).dt.date

# %%
df.isnull()
# Out:
#      Timestamp  العمر  النوع  نوع_الخدمة  زيارة_أولى  الفئة  سهولة_الحجز  \
# 0        False  False  False       False       False  False        False
# 1        False  False  False       False       False  False        False
# 2        False  False  False       False       False  False        False
# 3        False  False  False       False       False  False        False
# 4        False  False  False       False       False  False        False
# ..         ...    ...    ...         ...         ...    ...          ...
# 196      False  False  False       False       False  False        False
# 197      False  False  False       False       False  False        False
# 198      False  False  False       False       False  False        False
# 199      False  False  False       False       False  False        False
# 200      False  False  False       False       False  False        False
#
#      مدة_الانتظار_قبل_الكشف  سهولة_الوصول  وضوح_اللافتات  ...  سهولة_الخروج  \
# ...

# %%
df.isnull().sum()
# Out:
# Timestamp                     0
# العمر                         0
# النوع                         0
# نوع_الخدمة                    0
# زيارة_أولى                    0
# الفئة                         0
# سهولة_الحجز                   0
# مدة_الانتظار_قبل_الكشف        0
# سهولة_الوصول                  0
# وضوح_اللافتات                 0
# تعامل_الاستقبال               0
# مدة_انتظار_الاستقبال          0
# وضوح_الإجراءات                0
# نظافة_الانتظار                0
# مدة_الانتظار_قبل_الطبيب       0
# اهتمام_التمريض                0
# احترام_التمريض                0
# شرح_التمريض                   0
# استجابة_التمريض               0
# استماع_الطبيب                 0
# وقت_الطبيب                    0
# وضوح_الشرح                    0
# مشاركة_الطبيب                 0
# راحة_الأسئلة                  0
# إجابات_الطبيب                 0
# ثقة_بالطبيب                   0
# نظافة_الغرف                   0
# احترام_الخصوصية               0
# الهدوء                        0
# ...

# %%
df['راحة_الدفع'].fillna(df['راحة_الدفع'].mode()[0], inplace=True)
df['هل هناك طرق مختلفة للدفع؟'].fillna(df['هل هناك طرق مختلفة للدفع؟'].mode()[0], inplace=True)
df['نظافة_الممرات'].fillna(df['نظافة_الممرات'].mode()[0], inplace=True)
df['نظافة_الحمامات'].fillna(df['نظافة_الحمامات'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-1439192881.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['راحة_الدفع'].fillna(df['راحة_الدفع'].mode()[0], inplace=True)
# /tmp/ipython-input-1439192881.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  201 non-null    object
#  1   العمر                      201 non-null    object
#  2   النوع                      201 non-null    object
#  3   نوع_الخدمة                 201 non-null    object
#  4   زيارة_أولى                 201 non-null    object
#  5   الفئة                      201 non-null    object
#  6   سهولة_الحجز                201 non-null    int64
#  7   مدة_الانتظار_قبل_الكشف     201 non-null    object
#  8   سهولة_الوصول               201 non-null    int64
#  9   وضوح_اللافتات              201 non-null    object
#  10  تعامل_الاستقبال            201 non-null    int64
#  11  مدة_انتظار_الاستقبال       201 non-null    object
#  12  وضوح_الإجراءات             201 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['Timestamp', 'العمر', 'النوع', 'نوع_الخدمة', 'زيارة_أولى', 'الفئة',
#        'سهولة_الحجز', 'مدة_الانتظار_قبل_الكشف', 'سهولة_الوصول',
#        'وضوح_اللافتات', 'تعامل_الاستقبال', 'مدة_انتظار_الاستقبال',
#        'وضوح_الإجراءات', 'نظافة_الانتظار', 'مدة_الانتظار_قبل_الطبيب',
#        'اهتمام_التمريض', 'احترام_التمريض', 'شرح_التمريض', 'استجابة_التمريض',
#        'استماع_الطبيب', 'وقت_الطبيب', 'وضوح_الشرح', 'مشاركة_الطبيب',
#        'راحة_الأسئلة', 'إجابات_الطبيب', 'ثقة_بالطبيب', 'نظافة_الغرف',
#        'احترام_الخصوصية', 'الهدوء', 'جودة_الوجبات', 'سهولة_المرافق',
#        'شرح_الفحوصات', 'السيطرة_على_الألم', 'معلومات_الأدوية', 'تنسيق_الأقسام',
#        'وضوح_الفواتير', 'توضيح_التأمين', 'سهولة_الخروج', 'الرضا_العام',
#        'التوصية', 'أفضل_شيء', 'التحسينات', 'اقتراحات', 'راحة_الدفع',
#        'هل هناك طرق مختلفة للدفع؟', 'نظافة_الممرات', 'نظافة_الحمامات'],
#       dtype='object')

# %%
df['نظافة_الحمامات'] = df['نظافة_الحمامات'].astype(int)

# %%
df['نظافة_الممرات'] = df['نظافة_الممرات'].astype(int)

# %%
df['راحة_الدفع'] = df['راحة_الدفع'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 47 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  201 non-null    object
#  1   العمر                      201 non-null    object
#  2   النوع                      201 non-null    object
#  3   نوع_الخدمة                 201 non-null    object
#  4   زيارة_أولى                 201 non-null    object
#  5   الفئة                      201 non-null    object
#  6   سهولة_الحجز                201 non-null    int64
#  7   مدة_الانتظار_قبل_الكشف     201 non-null    object
#  8   سهولة_الوصول               201 non-null    int64
#  9   وضوح_اللافتات              201 non-null    object
#  10  تعامل_الاستقبال            201 non-null    int64
#  11  مدة_انتظار_الاستقبال       201 non-null    object
#  12  وضوح_الإجراءات             201 non-null    int64
# ...

# %%
df
# Out:
#       Timestamp              العمر النوع                 نوع_الخدمة  \
# 0    2025-09-28                 19   ذكر        كشف في عيادة خارجية
# 1    2025-09-28                 24   ذكر       إجراء فحوصات أو أشعة
# 2    2025-10-07  18 year - 29 year   ذكر               عملية جراحية
# 3    2025-10-07  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
# 4    2025-10-07  18 year - 29 year   ذكر                قسم الطوارئ
# ..          ...                ...   ...                        ...
# 196  2025-10-19  18 year - 29 year  أنثى        كشف في عيادة خارجية
# 197  2025-10-20  18 year - 29 year   ذكر  تنويم (إقامة في المستشفى)
# 198  2025-10-23  18 year - 29 year  أنثى       إجراء فحوصات أو أشعة
# 199  2025-10-26  18 year - 29 year   ذكر        كشف في عيادة خارجية
# 200  2025-10-26  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
#
#     زيارة_أولى  الفئة  سهولة_الحجز مدة_الانتظار_قبل_الكشف  سهولة_الوصول  \
# 0           لا   مريض            4        في حدود الساعة              1
# ...

# %%
cols = ['هل هناك طرق مختلفة للدفع؟', 'اقتراحات', 'التحسينات', 'أفضل_شيء']

df[cols] = df[cols].replace(['.', '..','...','N/a','-', 'X','.\n','N/a','. ','... ',' ',''], 'لا شي')

# %%
df
# Out:
#       Timestamp              العمر النوع                 نوع_الخدمة  \
# 0    2025-09-28                 19   ذكر        كشف في عيادة خارجية
# 1    2025-09-28                 24   ذكر       إجراء فحوصات أو أشعة
# 2    2025-10-07  18 year - 29 year   ذكر               عملية جراحية
# 3    2025-10-07  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
# 4    2025-10-07  18 year - 29 year   ذكر                قسم الطوارئ
# ..          ...                ...   ...                        ...
# 196  2025-10-19  18 year - 29 year  أنثى        كشف في عيادة خارجية
# 197  2025-10-20  18 year - 29 year   ذكر  تنويم (إقامة في المستشفى)
# 198  2025-10-23  18 year - 29 year  أنثى       إجراء فحوصات أو أشعة
# 199  2025-10-26  18 year - 29 year   ذكر        كشف في عيادة خارجية
# 200  2025-10-26  18 year - 29 year   ذكر       إجراء فحوصات أو أشعة
#
#     زيارة_أولى  الفئة  سهولة_الحجز مدة_الانتظار_قبل_الكشف  سهولة_الوصول  \
# 0           لا   مريض            4        في حدود الساعة              1
# ...

# %%
df.shape
# Out:
# (201, 47)

# %%
df.to_csv('hospital.csv', index=False)

# %%
from google.colab import files
files.download('hospital.csv')
